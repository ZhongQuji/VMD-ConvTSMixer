# %% [markdown]
# ### 运行前先装一个PyEMD库     是pip install pyemd pip install PyEMD，还是pip install EMD-signal 试着装哪个成功
# ### pip install -i https://pypi.tuna.tsinghua.edu.cn/simple xgboost 命令安装xgboost

# %%
# 调用相关库
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import pandas as pd
from math import sqrt
from numpy import concatenate
import matplotlib.pyplot as plt
import numpy as np
import random
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from PyEMD import CEEMDAN, Visualisation
from scipy.io import savemat,loadmat
from sklearn.metrics import mean_squared_error, mean_absolute_error
from pandas import DataFrame
from pandas import concat
import numpy
import os
import copy
import scipy as spy
import math
from scipy.spatial.distance import cdist
from numpy import dot, exp
import xgboost as xgb
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\xgboost\compat.py:31: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
# 转换成监督数据，将每个特征转换成21列数据，20->1，20组预测一组
def series_to_supervised(data, n_in=20, n_out=1, dropnan=True):
    n_vars = 1 if type(data) is list else data.shape[1]  #计算特征的数量
    df = pd.DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    # 将20组输入数据依次向下移动20,19,...3,2,1行，将数据加入cols列表（技巧：(n_in, 0, -1)中的-1指倒序循环，步长为1）
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    # 将一组输出数据加入cols列表（技巧：其中i=0）
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # cols列表(list)中现在有21块经过下移后的数据(即：df(-20),df(-19),...df(-2),df(-1),df)，将四块数据按列 并排合并
    agg = pd.concat(cols, axis=1)
    # 给合并后的数据添加列名
    agg.columns = names
    # print(agg)
    # 删除NaN值列
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# %%
dataset = pd.read_excel("816480.xlsx")
fratures_Corrected_irradiance = [
    'Flow (Veh/5 Minutes)'
]
values = dataset[fratures_Corrected_irradiance].values
n_features=1 #特征数量

# %%
values = values.astype('float32')
close = values

# %%
close=close.reshape(-1,1)
close.shape
# Out:
# (1440, 1)

# %%
ceemdan = CEEMDAN()  
# ceemdan = CEEMDAN(trials = 500,epsilon = 0.3)   
ceemdan.ceemdan(close.reshape(-1))
imfs_close, res_close = ceemdan.get_imfs_and_residue()

t = np.arange(0, close.shape[0], 1)
vis = Visualisation()
vis.plot_imfs(imfs=imfs_close, residue=res_close, t=t, include_residue=True)
# vis.plot_instant_freq(t, imfs=imfs)
vis.show()

# %%
prediction_test = []
actual_test = []

for imf in imfs_close:
    imf=imf.reshape(-1,1)
    imf=pd.DataFrame(imf)
    data_=imf.values
    data_ = data_.astype('float32')
    # 标准化/放缩 特征值在（0,1）之间
    scaler = StandardScaler()
    scaled = scaler.fit_transform(data_)
    
    n_in = 3
    n_out = 1
    # 构造一个20->1的监督学习型数据
    reframed = series_to_supervised(scaled, n_in=n_in, n_out=n_out)
    values=reframed.values
    
    #训练集和测试集的划分比例
    ratio=0.8 
    N=int(len(values) *ratio)
    train = values[:N, :]
    test = values[N:, :]

    # 划分输入和输出,split into input and outputs
    n_obs = n_in * n_features
    train_X, train_y = train[:, :-1], train[:, -1]
    test_X, test_y = test[:, :-1], test[:, -1]
    print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
    train_y=train_y.reshape(-1,1)
    
    
        # In[] 参数设置
    XGB = xgb.XGBRegressor(n_estimators=100,learning_rate = 0.03, max_depth=6,n_jobs=-1,)
    model= XGB.fit(train_X, train_y)
   
    
    
    
    #预测
    yhat = model.predict(test_X)
    yhat=yhat.reshape(-1,1)
    # 对预测结果进行反归一化
    inv_yhat = scaler.inverse_transform(yhat)
    prediction_test.append(inv_yhat)
    # 将真实列据进行反归一化
    test_y=test_y.reshape(-1,1)
    inv_y = scaler.inverse_transform(test_y)
    actual_test.append(inv_y)
    
    





#####残差
imf=res_close.reshape(-1,1)
imf=imf.reshape(-1,1)
imf=pd.DataFrame(imf)
data_=imf.values
data_ = data_.astype('float32')
#    标准化/放缩 特征值在（0,1）之间
scaler = StandardScaler()
scaled = scaler.fit_transform(data_)
    
n_in = 3
n_out = 1
# 构造一个20->1的监督学习型数据
reframed = series_to_supervised(scaled, n_in=n_in, n_out=n_out)
values=reframed.values
    
#训练集和测试集的划分比例
ratio=0.8 
N=int(len(values) *ratio)
train = values[:N, :]
test = values[N:, :]

# 划分输入和输出,split into input and outputs
n_obs = n_in * n_features
train_X, train_y = train[:, :-1], train[:, -1]
test_X, test_y = test[:, :-1], test[:, -1]
print(train_X.shape, train_y.shape, test_X.shape, test_y.shape)
train_y=train_y.reshape(-1,1)
    
XGB = xgb.XGBRegressor(n_estimators=100,learning_rate = 0.03, max_depth=6,n_jobs=-1,)
model= XGB.fit(train_X, train_y)
  
    
#预测
yhat = model.predict(test_X)
yhat=yhat.reshape(-1,1)
# 对预测结果进行反归一化
inv_yhat = scaler.inverse_transform(yhat)
prediction_test.append(inv_yhat)
# 将真实列据进行反归一化
test_y=test_y.reshape(-1,1)
inv_y = scaler.inverse_transform(test_y)
actual_test.append(inv_y)
# Out:
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)
# (1149, 3) (1149,) (288, 3) (288,)

# %%
mean_pre_test = []                    

for i in range(0,len(prediction_test[0])):
    sum = 0
    for j in range(0,len(prediction_test)):
        sum = sum + prediction_test[j][i]

    mean_pre_test.append(sum)
        
mean_pre_test
# Out:
# [array([145.75659], dtype=float32),
#  array([160.97644], dtype=float32),
#  array([166.39139], dtype=float32),
#  array([149.04587], dtype=float32),
#  array([158.8139], dtype=float32),
#  array([127.137634], dtype=float32),
#  array([116.01657], dtype=float32),
#  array([135.36606], dtype=float32),
#  array([155.53244], dtype=float32),
#  array([151.92023], dtype=float32),
#  array([111.99782], dtype=float32),
#  array([121.541245], dtype=float32),
#  array([120.115875], dtype=float32),
#  array([116.39984], dtype=float32),
#  array([106.32245], dtype=float32),
#  array([121.5896], dtype=float32),
#  array([116.14105], dtype=float32),
#  array([110.783966], dtype=float32),
#  array([105.258514], dtype=float32),
#  array([95.23108], dtype=float32),
#  array([100.263916], dtype=float32),
#  array([99.54141], dtype=float32),
#  array([101.23956], dtype=float32),
#  array([90.764694], dtype=float32),
#  array([95.364914], dtype=float32),
#  array([89.89378], dtype=float32),
#  array([105.00523], dtype=float32),
#  array([84.55615], dtype=float32),
#  array([85.91438], dtype=float32),
#  array([87.59538], dtype=float32),
#  array([91.48955], dtype=float32),
#  array([96.48424], dtype=float32),
#  array([87.038864], dtype=float32),
#  array([80.05699], dtype=float32),
#  array([84.24536], dtype=float32),
#  array([83.88971], dtype=float32),
#  array([81.676865], dtype=float32),
#  array([80.705505], dtype=float32),
#  array([76.47739], dtype=float32),
#  array([80.43883], dtype=float32),
#  array([93.67923], dtype=float32),
#  array([96.83148], dtype=float32),
#  array([111.48244], dtype=float32),
#  array([120.80165], dtype=float32),
#  array([126.24576], dtype=float32),
#  array([141.4442], dtype=float32),
#  array([138.46272], dtype=float32),
#  array([116.73723], dtype=float32),
#  array([106.08847], dtype=float32),
#  array([106.880905], dtype=float32),
#  array([110.86267], dtype=float32),
#  array([116.939514], dtype=float32),
#  array([122.28349], dtype=float32),
#  array([110.3759], dtype=float32),
#  array([150.47592], dtype=float32),
#  array([174.4979], dtype=float32),
#  array([214.49973], dtype=float32),
#  array([215.7858], dtype=float32),
#  array([205.8092], dtype=float32),
#  array([173.76439], dtype=float32),
#  array([163.1751], dtype=float32),
#  array([144.15094], dtype=float32),
#  array([181.24377], dtype=float32),
#  array([206.73544], dtype=float32),
#  array([211.30641], dtype=float32),
#  array([216.45453], dtype=float32),
#  array([241.58992], dtype=float32),
#  array([259.4101], dtype=float32),
#  array([325.04], dtype=float32),
#  array([368.00983], dtype=float32),
#  array([367.51596], dtype=float32),
#  array([349.05774], dtype=float32),
#  array([345.7928], dtype=float32),
#  array([310.4496], dtype=float32),
#  array([309.6484], dtype=float32),
#  array([311.94244], dtype=float32),
#  array([272.13187], dtype=float32),
#  array([323.98624], dtype=float32),
#  array([339.31335], dtype=float32),
#  array([392.98364], dtype=float32),
#  array([408.84753], dtype=float32),
#  array([462.17114], dtype=float32),
#  array([444.71246], dtype=float32),
#  array([442.77524], dtype=float32),
#  array([427.55728], dtype=float32),
#  array([408.37494], dtype=float32),
#  array([439.07404], dtype=float32),
#  array([459.37317], dtype=float32),
#  array([481.84125], dtype=float32),
#  array([513.53894], dtype=float32),
#  array([453.7436], dtype=float32),
#  array([514.6848], dtype=float32),
#  array([548.75903], dtype=float32),
#  array([560.03845], dtype=float32),
#  array([509.62524], dtype=float32),
#  array([499.41458], dtype=float32),
#  array([469.8523], dtype=float32),
#  array([392.2174], dtype=float32),
#  array([352.18936], dtype=float32),
#  array([433.68875], dtype=float32),
#  array([448.50336], dtype=float32),
#  array([458.88086], dtype=float32),
#  array([450.47345], dtype=float32),
#  array([402.17538], dtype=float32),
#  array([415.02948], dtype=float32),
#  array([436.85913], dtype=float32),
#  array([460.7407], dtype=float32),
#  array([443.96362], dtype=float32),
#  array([395.55182], dtype=float32),
#  array([376.2509], dtype=float32),
#  array([381.0905], dtype=float32),
#  array([414.59634], dtype=float32),
#  array([439.87375], dtype=float32),
#  array([429.09705], dtype=float32),
#  array([421.08148], dtype=float32),
#  array([420.1983], dtype=float32),
#  array([421.63403], dtype=float32),
#  array([443.98727], dtype=float32),
#  array([426.04465], dtype=float32),
#  array([412.79242], dtype=float32),
#  array([444.52536], dtype=float32),
#  array([460.37973], dtype=float32),
#  array([451.1769], dtype=float32),
#  array([459.89], dtype=float32),
#  array([454.52008], dtype=float32),
#  array([414.6598], dtype=float32),
#  array([420.17865], dtype=float32),
#  array([445.28647], dtype=float32),
#  array([441.03772], dtype=float32),
#  array([444.03098], dtype=float32),
#  array([458.80627], dtype=float32),
#  array([456.6497], dtype=float32),
#  array([453.2588], dtype=float32),
#  array([479.24872], dtype=float32),
#  array([485.7606], dtype=float32),
#  array([476.34125], dtype=float32),
#  array([489.4328], dtype=float32),
#  array([470.0615], dtype=float32),
#  array([448.55658], dtype=float32),
#  array([468.82605], dtype=float32),
#  array([468.05826], dtype=float32),
#  array([476.8539], dtype=float32),
#  array([512.6396], dtype=float32),
#  array([505.76587], dtype=float32),
#  array([507.4748], dtype=float32),
#  array([523.3182], dtype=float32),
#  array([497.52832], dtype=float32),
#  array([514.08954], dtype=float32),
#  array([531.32294], dtype=float32),
#  array([499.2441], dtype=float32),
#  array([536.4773], dtype=float32),
#  array([532.049], dtype=float32),
#  array([545.776], dtype=float32),
#  array([519.6133], dtype=float32),
#  array([526.43604], dtype=float32),
#  array([538.151], dtype=float32),
#  array([552.3379], dtype=float32),
#  array([571.7101], dtype=float32),
#  array([563.7611], dtype=float32),
#  array([567.4538], dtype=float32),
#  array([551.6263], dtype=float32),
#  array([528.7813], dtype=float32),
#  array([525.55383], dtype=float32),
#  array([512.32654], dtype=float32),
#  array([536.06354], dtype=float32),
#  array([535.7513], dtype=float32),
#  array([521.37244], dtype=float32),
#  array([514.2239], dtype=float32),
#  array([534.99335], dtype=float32),
#  array([534.4326], dtype=float32),
#  array([517.16455], dtype=float32),
#  array([484.86853], dtype=float32),
#  array([512.2506], dtype=float32),
#  array([537.0293], dtype=float32),
#  array([550.14264], dtype=float32),
#  array([528.34576], dtype=float32),
#  array([512.4735], dtype=float32),
#  array([474.30872], dtype=float32),
#  array([483.4312], dtype=float32),
#  array([488.44458], dtype=float32),
#  array([527.1758], dtype=float32),
#  array([531.61414], dtype=float32),
#  array([511.14856], dtype=float32),
#  array([513.13043], dtype=float32),
#  array([525.7496], dtype=float32),
#  array([516.9326], dtype=float32),
#  array([512.34314], dtype=float32),
#  array([530.6266], dtype=float32),
#  array([487.148], dtype=float32),
#  array([499.0187], dtype=float32),
#  array([468.16904], dtype=float32),
#  array([498.09766], dtype=float32),
#  array([498.5388], dtype=float32),
#  array([471.6541], dtype=float32),
#  array([475.23846], dtype=float32),
#  array([483.21234], dtype=float32),
#  array([500.5431], dtype=float32),
#  array([492.80463], dtype=float32),
#  array([488.28714], dtype=float32),
#  array([503.84747], dtype=float32),
#  array([476.89252], dtype=float32),
#  array([496.10046], dtype=float32),
#  array([461.161], dtype=float32),
#  array([472.48904], dtype=float32),
#  array([465.38873], dtype=float32),
#  array([467.37653], dtype=float32),
#  array([489.92813], dtype=float32),
#  array([455.94037], dtype=float32),
#  array([437.08783], dtype=float32),
#  array([454.26843], dtype=float32),
#  array([466.3868], dtype=float32),
#  array([477.50168], dtype=float32),
#  array([472.33527], dtype=float32),
#  array([461.8521], dtype=float32),
#  array([449.61182], dtype=float32),
#  array([501.81442], dtype=float32),
#  array([534.9228], dtype=float32),
#  array([506.46127], dtype=float32),
#  array([476.7607], dtype=float32),
#  array([467.7336], dtype=float32),
#  array([453.4524], dtype=float32),
#  array([458.39917], dtype=float32),
#  array([477.03354], dtype=float32),
#  array([483.69318], dtype=float32),
#  array([495.92493], dtype=float32),
#  array([476.86182], dtype=float32),
#  array([487.85574], dtype=float32),
#  array([437.43594], dtype=float32),
#  array([397.59845], dtype=float32),
#  array([393.8268], dtype=float32),
#  array([445.77768], dtype=float32),
#  array([489.07364], dtype=float32),
#  array([492.1993], dtype=float32),
#  array([519.7975], dtype=float32),
#  array([492.6022], dtype=float32),
#  array([461.46985], dtype=float32),
#  array([436.11777], dtype=float32),
#  array([420.5857], dtype=float32),
#  array([425.28662], dtype=float32),
#  array([416.42715], dtype=float32),
#  array([433.05276], dtype=float32),
#  array([391.60706], dtype=float32),
#  array([387.9417], dtype=float32),
#  array([428.00134], dtype=float32),
#  array([418.4069], dtype=float32),
#  array([391.48666], dtype=float32),
#  array([413.61035], dtype=float32),
#  array([418.16418], dtype=float32),
#  array([383.1755], dtype=float32),
#  array([368.3331], dtype=float32),
#  array([420.07666], dtype=float32),
#  array([425.3775], dtype=float32),
#  array([444.8794], dtype=float32),
#  array([441.7403], dtype=float32),
#  array([419.60904], dtype=float32),
#  array([413.65146], dtype=float32),
#  array([409.42838], dtype=float32),
#  array([454.59167], dtype=float32),
#  array([449.63123], dtype=float32),
#  array([435.5641], dtype=float32),
#  array([372.88043], dtype=float32),
#  array([407.3098], dtype=float32),
#  array([349.7459], dtype=float32),
#  array([354.00287], dtype=float32),
#  array([360.63205], dtype=float32),
#  array([353.70267], dtype=float32),
#  array([349.07452], dtype=float32),
#  array([364.24725], dtype=float32),
#  array([360.13116], dtype=float32),
#  array([329.98514], dtype=float32),
#  array([318.8353], dtype=float32),
#  array([312.26202], dtype=float32),
#  array([313.97247], dtype=float32),
#  array([305.71854], dtype=float32),
#  array([292.56787], dtype=float32),
#  array([247.03125], dtype=float32),
#  array([269.73468], dtype=float32),
#  array([275.2097], dtype=float32),
#  array([271.91336], dtype=float32),
#  array([250.90266], dtype=float32),
#  array([240.30586], dtype=float32),
#  array([228.79308], dtype=float32),
#  array([223.08887], dtype=float32),
#  array([218.55357], dtype=float32),
#  array([215.07208], dtype=float32),
#  array([227.86748], dtype=float32),
#  array([251.70107], dtype=float32),
#  array([256.93845], dtype=float32)]

# %%
mean_actual_test = []

for i in range(0,len(actual_test[0])):
    sum = 0
    for j in range(0,len(actual_test)):
        sum = sum + actual_test[j][i]

    mean_actual_test.append(sum)
        
mean_actual_test
# Out:
# [array([114.000015], dtype=float32),
#  array([104.999985], dtype=float32),
#  array([91.000015], dtype=float32),
#  array([176.00002], dtype=float32),
#  array([141.00002], dtype=float32),
#  array([110.999985], dtype=float32),
#  array([107.999985], dtype=float32),
#  array([111.], dtype=float32),
#  array([121.999985], dtype=float32),
#  array([136.], dtype=float32),
#  array([88.99997], dtype=float32),
#  array([105.000015], dtype=float32),
#  array([84.], dtype=float32),
#  array([88.999985], dtype=float32),
#  array([79.000015], dtype=float32),
#  array([101.999985], dtype=float32),
#  array([107.], dtype=float32),
#  array([76.], dtype=float32),
#  array([85.], dtype=float32),
#  array([70.999985], dtype=float32),
#  array([78.00003], dtype=float32),
#  array([75.999985], dtype=float32),
#  array([84.000015], dtype=float32),
#  array([57.], dtype=float32),
#  array([85.00003], dtype=float32),
#  array([71.000015], dtype=float32),
#  array([83.], dtype=float32),
#  array([61.], dtype=float32),
#  array([61.], dtype=float32),
#  array([64.99997], dtype=float32),
#  array([67.], dtype=float32),
#  array([83.000015], dtype=float32),
#  array([70.], dtype=float32),
#  array([53.00003], dtype=float32),
#  array([72.000015], dtype=float32),
#  array([71.], dtype=float32),
#  array([52.], dtype=float32),
#  array([59.00003], dtype=float32),
#  array([57.00003], dtype=float32),
#  array([56.99997], dtype=float32),
#  array([78.], dtype=float32),
#  array([74.99997], dtype=float32),
#  array([85.], dtype=float32),
#  array([108.999985], dtype=float32),
#  array([106.], dtype=float32),
#  array([118.999985], dtype=float32),
#  array([131.00002], dtype=float32),
#  array([111.999985], dtype=float32),
#  array([81.], dtype=float32),
#  array([87.], dtype=float32),
#  array([106.000015], dtype=float32),
#  array([104.00003], dtype=float32),
#  array([113.], dtype=float32),
#  array([87.000015], dtype=float32),
#  array([166.], dtype=float32),
#  array([152.], dtype=float32),
#  array([185.00002], dtype=float32),
#  array([199.99998], dtype=float32),
#  array([203.], dtype=float32),
#  array([150.00002], dtype=float32),
#  array([154.], dtype=float32),
#  array([131.], dtype=float32),
#  array([162.], dtype=float32),
#  array([208.99998], dtype=float32),
#  array([228.], dtype=float32),
#  array([207.], dtype=float32),
#  array([247.99998], dtype=float32),
#  array([261.00003], dtype=float32),
#  array([334.], dtype=float32),
#  array([389.], dtype=float32),
#  array([359.], dtype=float32),
#  array([329.99997], dtype=float32),
#  array([290.], dtype=float32),
#  array([270.], dtype=float32),
#  array([274.], dtype=float32),
#  array([298.99997], dtype=float32),
#  array([327.], dtype=float32),
#  array([329.99997], dtype=float32),
#  array([347.], dtype=float32),
#  array([377.], dtype=float32),
#  array([447.99997], dtype=float32),
#  array([474.], dtype=float32),
#  array([487.], dtype=float32),
#  array([422.], dtype=float32),
#  array([417.], dtype=float32),
#  array([378.99997], dtype=float32),
#  array([408.], dtype=float32),
#  array([471.], dtype=float32),
#  array([502.], dtype=float32),
#  array([446.], dtype=float32),
#  array([450.], dtype=float32),
#  array([483.], dtype=float32),
#  array([588.], dtype=float32),
#  array([521.], dtype=float32),
#  array([498.], dtype=float32),
#  array([523.], dtype=float32),
#  array([412.], dtype=float32),
#  array([388.], dtype=float32),
#  array([373.], dtype=float32),
#  array([444.], dtype=float32),
#  array([416.], dtype=float32),
#  array([434.], dtype=float32),
#  array([455.], dtype=float32),
#  array([399.], dtype=float32),
#  array([436.], dtype=float32),
#  array([430.], dtype=float32),
#  array([448.], dtype=float32),
#  array([461.], dtype=float32),
#  array([392.], dtype=float32),
#  array([353.99997], dtype=float32),
#  array([349.99997], dtype=float32),
#  array([424.00003], dtype=float32),
#  array([424.99997], dtype=float32),
#  array([433.99997], dtype=float32),
#  array([420.], dtype=float32),
#  array([428.], dtype=float32),
#  array([408.], dtype=float32),
#  array([470.], dtype=float32),
#  array([473.], dtype=float32),
#  array([393.], dtype=float32),
#  array([430.00003], dtype=float32),
#  array([467.], dtype=float32),
#  array([436.], dtype=float32),
#  array([451.], dtype=float32),
#  array([454.], dtype=float32),
#  array([450.99997], dtype=float32),
#  array([393.00003], dtype=float32),
#  array([477.], dtype=float32),
#  array([446.], dtype=float32),
#  array([433.], dtype=float32),
#  array([474.], dtype=float32),
#  array([464.], dtype=float32),
#  array([450.], dtype=float32),
#  array([479.], dtype=float32),
#  array([502.99997], dtype=float32),
#  array([475.], dtype=float32),
#  array([505.99997], dtype=float32),
#  array([478.], dtype=float32),
#  array([449.], dtype=float32),
#  array([479.00003], dtype=float32),
#  array([467.], dtype=float32),
#  array([474.], dtype=float32),
#  array([535.], dtype=float32),
#  array([546.], dtype=float32),
#  array([513.], dtype=float32),
#  array([553.], dtype=float32),
#  array([488.], dtype=float32),
#  array([507.], dtype=float32),
#  array([539.], dtype=float32),
#  array([512.], dtype=float32),
#  array([561.], dtype=float32),
#  array([534.], dtype=float32),
#  array([556.], dtype=float32),
#  array([547.], dtype=float32),
#  array([541.], dtype=float32),
#  array([541.], dtype=float32),
#  array([549.], dtype=float32),
#  array([592.], dtype=float32),
#  array([573.], dtype=float32),
#  array([565.], dtype=float32),
#  array([567.], dtype=float32),
#  array([532.], dtype=float32),
#  array([541.], dtype=float32),
#  array([519.], dtype=float32),
#  array([523.], dtype=float32),
#  array([573.], dtype=float32),
#  array([567.], dtype=float32),
#  array([507.], dtype=float32),
#  array([533.], dtype=float32),
#  array([556.], dtype=float32),
#  array([558.], dtype=float32),
#  array([510.], dtype=float32),
#  array([505.], dtype=float32),
#  array([533.], dtype=float32),
#  array([570.], dtype=float32),
#  array([535.], dtype=float32),
#  array([525.], dtype=float32),
#  array([478.], dtype=float32),
#  array([517.], dtype=float32),
#  array([492.], dtype=float32),
#  array([537.], dtype=float32),
#  array([563.], dtype=float32),
#  array([523.], dtype=float32),
#  array([509.], dtype=float32),
#  array([509.], dtype=float32),
#  array([515.], dtype=float32),
#  array([519.], dtype=float32),
#  array([566.], dtype=float32),
#  array([489.], dtype=float32),
#  array([521.], dtype=float32),
#  array([477.], dtype=float32),
#  array([532.], dtype=float32),
#  array([496.99997], dtype=float32),
#  array([484.], dtype=float32),
#  array([506.], dtype=float32),
#  array([493.], dtype=float32),
#  array([525.], dtype=float32),
#  array([536.], dtype=float32),
#  array([481.], dtype=float32),
#  array([481.], dtype=float32),
#  array([518.], dtype=float32),
#  array([526.], dtype=float32),
#  array([454.], dtype=float32),
#  array([497.], dtype=float32),
#  array([504.], dtype=float32),
#  array([489.], dtype=float32),
#  array([505.], dtype=float32),
#  array([476.], dtype=float32),
#  array([439.], dtype=float32),
#  array([488.99997], dtype=float32),
#  array([520.], dtype=float32),
#  array([469.], dtype=float32),
#  array([479.99997], dtype=float32),
#  array([497.], dtype=float32),
#  array([450.99997], dtype=float32),
#  array([563.], dtype=float32),
#  array([490.], dtype=float32),
#  array([513.], dtype=float32),
#  array([480.], dtype=float32),
#  array([489.], dtype=float32),
#  array([453.00003], dtype=float32),
#  array([502.00003], dtype=float32),
#  array([514.], dtype=float32),
#  array([493.], dtype=float32),
#  array([515.], dtype=float32),
#  array([465.], dtype=float32),
#  array([518.], dtype=float32),
#  array([455.], dtype=float32),
#  array([361.], dtype=float32),
#  array([454.], dtype=float32),
#  array([462.], dtype=float32),
#  array([510.], dtype=float32),
#  array([519.], dtype=float32),
#  array([537.], dtype=float32),
#  array([502.99997], dtype=float32),
#  array([439.00003], dtype=float32),
#  array([418.], dtype=float32),
#  array([419.], dtype=float32),
#  array([439.], dtype=float32),
#  array([401.], dtype=float32),
#  array([442.00003], dtype=float32),
#  array([424.99997], dtype=float32),
#  array([374.], dtype=float32),
#  array([454.], dtype=float32),
#  array([410.00003], dtype=float32),
#  array([381.99997], dtype=float32),
#  array([397.], dtype=float32),
#  array([413.], dtype=float32),
#  array([393.00003], dtype=float32),
#  array([377.], dtype=float32),
#  array([439.00003], dtype=float32),
#  array([416.], dtype=float32),
#  array([427.00003], dtype=float32),
#  array([466.], dtype=float32),
#  array([462.00003], dtype=float32),
#  array([428.], dtype=float32),
#  array([380.], dtype=float32),
#  array([427.], dtype=float32),
#  array([479.], dtype=float32),
#  array([425.], dtype=float32),
#  array([347.00003], dtype=float32),
#  array([400.], dtype=float32),
#  array([387.], dtype=float32),
#  array([315.], dtype=float32),
#  array([364.], dtype=float32),
#  array([366.], dtype=float32),
#  array([346.], dtype=float32),
#  array([357.], dtype=float32),
#  array([351.], dtype=float32),
#  array([317.], dtype=float32),
#  array([315.], dtype=float32),
#  array([307.], dtype=float32),
#  array([317.], dtype=float32),
#  array([289.], dtype=float32),
#  array([282.], dtype=float32),
#  array([228.99997], dtype=float32),
#  array([280.], dtype=float32),
#  array([263.], dtype=float32),
#  array([270.99997], dtype=float32),
#  array([240.], dtype=float32),
#  array([244.00003], dtype=float32),
#  array([235.], dtype=float32),
#  array([206.], dtype=float32),
#  array([179.], dtype=float32),
#  array([185.00002], dtype=float32),
#  array([234.00002], dtype=float32),
#  array([269.], dtype=float32),
#  array([200.], dtype=float32)]

# %%
# 计算RMSE
def mape(y_true, y_pred):
    #评价指标MAPE
    record=[]
    for index in range(len(y_true)):
        if abs(y_true[index])>10:
            temp_mape=np.abs((y_pred[index] - y_true[index]) / y_true[index])
            record.append(temp_mape)
    return np.mean(record) * 100
rmse = sqrt(mean_squared_error(mean_actual_test, mean_pre_test))
print('Test RMSE: %.7f' % rmse)
print('Test MAE: %.7f' % mean_absolute_error(mean_actual_test, mean_pre_test))
print('Test MAPE: %.7f' % mape(mean_actual_test, mean_pre_test))
print('Test R2: %.7f' % r2_score(mean_actual_test, mean_pre_test))
# Out:
# Test RMSE: 23.1164179
# Test MAE: 18.6369381
# Test MAPE: 8.7183625
# Test R2: 0.9799359

# %%
# 测试集
import seaborn as sns
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['font.sans-serif']=['Simhei']  #解决画图中文不显示问题
plt.figure(figsize=(6,4),dpi=600)
x=range(1, len(mean_pre_test) + 1)
plt.xticks(x[::50])
plt.tick_params(labelsize=10)  #改变刻度字体大小
plt.plot(x, mean_actual_test, linestyle="--",color='g',linewidth=1, label='Acture')
plt.plot(x, mean_pre_test,  color='red',linestyle="--",linewidth=1,label='CEEMDAN-XGBoost')
plt.rcParams.update({'font.size': 10})  #改变图例里面的字体大小
plt.legend(loc='upper right')
plt.xlabel("样本点",fontsize=10)
plt.ylabel("值",fontsize=10)
# plt.xlim(xmin=600,xmax=700)  #显示600-1000的值   局部放大有利于观察
# plt.savefig('台湾VMD-LSTM震级预测结果图.png')
plt.show()

# %%
# #保存预测结果
savemat('结果/ceemdan_xgboost_result.mat',{'true':mean_actual_test,'pred':mean_pre_test})
